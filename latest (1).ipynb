# %% [markdown]
# Basic Imports for Pytorch

# %%
# Importing required libraries
import torch.nn as nn
import torch
import torchvision.transforms as transforms
import torchvision.datasets as datasets
import os
from torch.utils.data import DataLoader
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# ### Defining helper functions
#
#
# 1.   Progress Bar: To help with verbose training information and progress visualization.
# 2.   Cutout: A regularization tool to help with augmentation, as proposed by DeVries and Taylor (2017), https://arxiv.org/pdf/1708.04552.pdf

# %%
import sys
import numpy as np
from PIL import Image


class ProgressBar:

    def __init__(self, width=30):
        self.width = width

    def update(self, max_value, current_value, info):
        progress = int(round(self.width * current_value / max_value))
        bar = '=' * progress + '.' * (self.width - progress)
        prefix = '{}/{}'.format(current_value, max_value)

        prefix_max_len = len('{}/{}'.format(max_value, max_value))
        buffer = ' ' * (prefix_max_len - len(prefix))

        sys.stdout.write('\r {} {} [{}] - {}'.format(prefix, buffer, bar, info))
        sys.stdout.flush()

    def new_line(self):
        print()

# Cutout basically covers a region of an input image. Its a data augmentation technique
class Cutout(object):
    def __init__(self, num_cutouts, size, p=0.5):
        self.num_cutouts = num_cutouts
        self.size = size
        self.p = p

    def __call__(self, img):

        height, width = img.size

        cutouts = np.ones((height, width))

        if np.random.uniform() < 1 - self.p:
            return img

        for i in range(self.num_cutouts):
            y_center = np.random.randint(0, height)
            x_center = np.random.randint(0, width)

            y1 = np.clip(y_center - self.size // 2, 0, height)
            y2 = np.clip(y_center + self.size // 2, 0, height)
            x1 = np.clip(x_center - self.size // 2, 0, width)
            x2 = np.clip(x_center + self.size // 2, 0, width)

            cutouts[y1:y2, x1:x2] = 0

        cutouts = np.broadcast_to(cutouts, (3, height, width))
        cutouts = np.moveaxis(cutouts, 0, 2)
        img = np.array(img)
        img = img * cutouts
        return Image.fromarray(img.astype('uint8'), 'RGB')

# %% [markdown]
# # Loading the CIFAR-10 dataset.
# ## Additionally defining Augmentation Transformations for it and Normalizing the data.

# %%
# Configuring parameters given by wandb.ai for cutout
train_transform = transforms.Compose([
            Cutout(num_cutouts=2, size=8, p=0.8),
            transforms.RandomCrop(32, padding=4),
            transforms.RandomHorizontalFlip(),
            transforms.ToTensor(),
            transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
        ])
test_transform = transforms.Compose([transforms.ToTensor(),
                                             transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
                                             ])
# train and test dataset
train_dataset = datasets.CIFAR10('data/cifar', train=True, download=True, transform=train_transform)

test_dataset = datasets.CIFAR10('data/cifar', train=False, download=True, transform=test_transform)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to data/cifar/cifar-10-python.tar.gz
# 100%|██████████| 170498071/170498071 [00:02<00:00, 68364667.38it/s]
# Extracting data/cifar/cifar-10-python.tar.gz to data/cifar
# Files already downloaded and verified

# %% [markdown]
# ##Test Function to test the model

# %%
def test(model, batch_size=256):
        model.eval()

        data_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, num_workers=2)

        correct = 0
        total = 0
        with torch.no_grad():
            for i, data in enumerate(data_loader, 0):
                images, labels = data
                images = images.to(device)
                labels = labels.to(device)

                outputs = model(images)
                _, predicted = torch.max(outputs, dim=1)
                total += labels.size(0)
                correct += (predicted == labels.flatten()).sum().item()

        model.train()
        return correct / total

# %% [markdown]
# Helper Function to build the optimizer:

# %%
# we shall use sgd and adam optimizer
def build_optimizer(network, optimizer, learning_rate):
    if optimizer == "sgd":
        optimizer = torch.optim.SGD(network.parameters(),
                              lr=learning_rate, momentum=0.9)
    elif optimizer == "adam":
        optimizer = torch.optim.Adam(network.parameters(),
                               lr=learning_rate)
    return optimizer

# %% [markdown]
# #Model Definition for hyperparameter sweep.
# This is a modified ResNet model, with the architecture shown below.
#
# ![ResNet Architecture.png](data:image/png;base64,...)

# %%
# Basic block are labeled in the diagram as res1 and res 2
class BasicBlock(nn.Module):
    def __init__(self, in_channels, out_channels,kernel_size=3, stride=1, padding=1):
        super().__init__()

        self.conv1 = nn.Conv2d(in_channels, out_channels, kernel_size, stride=stride, padding=padding, bias=False)
        self.bn1 = nn.BatchNorm2d(out_channels)
        self.relu = nn.ReLU(inplace=True)
        self.conv2 = nn.Conv2d(out_channels, out_channels, kernel_size, stride=1, padding=padding, bias=False)
        self.bn2 = nn.BatchNorm2d(out_channels)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_channels != out_channels:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_channels, out_channels, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(out_channels)
            )
    def forward(self, x):
        residual = self.shortcut(x)

        out = self.conv1(x)
        out = self.bn1(out)
        out = self.relu(out)

        out = self.conv2(out)
        out = self.bn2(out)

        out += residual
        out = self.relu(out)

        return out

# Modified ResNet9 Network
class ResNet9(nn.Module):
    def __init__(self, activation='relu', fc_size=1024, dropout=0.5):
        super(ResNet9, self).__init__()

        self.conv = nn.Sequential(
            nn.Conv2d(in_channels=3, out_channels=64, kernel_size=3, stride=1, padding=1, bias=False),
            nn.BatchNorm2d(num_features=64, momentum=0.9),
            nn.ReLU(inplace=True),
            # These 4 lines of code are the first subpart of residual block 1
            nn.Conv2d(in_channels=64, out_channels=128, kernel_size=3, stride=1, padding=1, bias=False),
            nn.BatchNorm2d(num_features=128, momentum=0.9),
            nn.ReLU(inplace=True),
            # This pooling layer will have a skipped connection to the end
            nn.MaxPool2d(kernel_size=2, stride=2),
            # Basic block are res 1 and res 2 combined 
            BasicBlock(in_channels=128, out_channels=128, kernel_size=3, stride=1, padding=1),
            # This ends the first residual block
            # The next 4 lines of code are conv block
            nn.Conv2d(in_channels=128, out_channels=256, kernel_size=3, stride=1, padding=1, bias=False),
            nn.BatchNorm2d(num_features=256, momentum=0.9),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),
            # These last lines are residual block 2 as labeled in the architecture diagram
            nn.Conv2d(in_channels=256, out_channels=256, kernel_size=3, stride=1, padding=1, bias=False),
            nn.BatchNorm2d(num_features=256, momentum=0.9),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),
            BasicBlock(in_channels=256, out_channels=256, kernel_size=3, stride=1, padding=1),
            nn.MaxPool2d(kernel_size=2, stride=2),
        )
        # classifier block
        if activation == "relu":
            self.fc = nn.Sequential(
                nn.Linear(in_features=1024, out_features=fc_size, bias=True),
                nn.Dropout(p=dropout),
                nn.ReLU(inplace=True),
                nn.BatchNorm1d(num_features=fc_size, momentum=0.9),
                nn.Linear(in_features=fc_size, out_features=10, bias=True)
            )
        elif activation == "sigmoid":
            self.fc = nn.Sequential(
                nn.Linear(in_features=1024, out_features=fc_size, bias=True),
                nn.Dropout(p=dropout),
                nn.Sigmoid(),
                nn.BatchNorm1d(num_features=fc_size, momentum=0.9),
                nn.Linear(in_features=fc_size, out_features=10, bias=True)
            )
        
    def forward(self, x):
        out = self.conv(x)
        out = out.view(-1, out.shape[1] * out.shape[2] * out.shape[3])
        out = self.fc(out)
        return out

# %% [markdown]
# Training the network with the best params as per wandb.
# ![best_params.png](data:image/png;base64,...)

# %%
def train(activation="relu", fc_size=1024, dropout=0.25, optimizer="adam", learning_rate=0.001, epochs=75, batch_size=128):
    
    model = ResNet9(activation=activation, fc_size=fc_size, dropout=dropout).to(device)
    print(f"Number of trainable parameters: {sum(p.numel() for p in model.parameters() if p.requires_grad)}")
    optimizer = build_optimizer(model, optimizer, learning_rate)
    model.train()
    criterion = nn.CrossEntropyLoss()
    trainloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=2)
    best_accuracy=0
    progress_bar = ProgressBar()

    for epoch in range(1, epochs + 1):
        print('Epoch {}/{}'.format(epoch,epochs))
        running_loss = 0
        epoch_correct = 0
        epoch_total = 0
        for i, (inputs, targets) in enumerate(trainloader):

            inputs, targets = inputs.to(device), targets.to(device)

            # parameter gradients -> Zero
            optimizer.zero_grad()

            # Forward + backward + optimizer
            outputs = model(inputs)
            loss = criterion(outputs, targets)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()
            _, predicted = outputs.max(1)
            batch_total = targets.size(0)
            batch_correct = predicted.eq(targets).sum().item()


            epoch_total += batch_total
            epoch_correct += batch_correct


            info_str = 'Last batch accuracy: {:.4f} - Running epoch accuracy {:.4f}'.\
                        format(batch_correct / batch_total, epoch_correct / epoch_total)
            progress_bar.update(max_value=len(trainloader), current_value=i, info=info_str)

        progress_bar.new_line()
        test_accuracy = test(model)
        if epoch > 30 and test_accuracy>best_accuracy:
            torch.save(model.state_dict(), "best_model.pth")
            best_accuracy=test_accuracy
            
        print('Test accuracy: {:.2f}% Loss: {:.4f}'.format(test_accuracy*100,running_loss))
    print('Best accuracy: {:.2f}%'.format(best_accuracy*100))

# %% [markdown]
# Now we shall run the above model in 75 epochs and monitor the test accuracy we get

# %%
train()
# Out:
# Number of trainable parameters: 3499594
# Epoch 1/75
#  390/391  [==============================] - Last batch accuracy: 0.6375 - Running epoch accuracy 0.4901
# Test accuracy: 65.35% Loss: 544.8148
# Epoch 2/75
#  390/391  [==============================] - Last batch accuracy: 0.6500 - Running epoch accuracy 0.6750
# Test accuracy: 71.82% Loss: 360.2338
# Epoch 3/75
#  390/391  [==============================] - Last batch accuracy: 0.7000 - Running epoch accuracy 0.7341
# Test accuracy: 75.71% Loss: 297.3055
# Epoch 4/75
#  390/391  [==============================] - Last batch accuracy: 0.8000 - Running epoch accuracy 0.7567
# Test accuracy: 78.99% Loss: 273.8851
# Epoch 5/75
#  390/391  [==============================] - Last batch accuracy: 0.6875 - Running epoch accuracy 0.7886
# Test accuracy: 81.71% Loss: 238.2189
# Epoch 6/75
#  390/391  [==============================] - Last batch accuracy: 0.8000 - Running epoch accuracy 0.8115
# Test accuracy: 83.83% Loss: 214.9684
# Epoch 7/75
#  390/391  [==============================] - Last batch accuracy: 0.7500 - Running epoch accuracy 0.8250
# Test accuracy: 84.44% Loss: 197.7645
# Epoch 8/75
#  390/391  [==============================] - Last batch accuracy: 0.8250 - Running epoch accuracy 0.8366
# Test accuracy: 84.81% Loss: 184.3567
# Epoch 9/75
#  390/391  [==============================] - Last batch accuracy: 0.8375 - Running epoch accuracy 0.8483
# Test accuracy: 86.55% Loss: 169.9967
# Epoch 10/75
#  390/391  [==============================] - Last batch accuracy: 0.9375 - Running epoch accuracy 0.8601
# Test accuracy: 87.49% Loss: 158.2127
# Epoch 11/75
#  390/391  [==============================] - Last batch accuracy: 0.8750 - Running epoch accuracy 0.8664
# Test accuracy: 86.77% Loss: 151.4684
# Epoch 12/75
#  390/391  [==============================] - Last batch accuracy: 0.8375 - Running epoch accuracy 0.8739
# Test accuracy: 87.43% Loss: 142.1013
# Epoch 13/75
#  390/391  [==============================] - Last batch accuracy: 0.8875 - Running epoch accuracy 0.8803
# Test accuracy: 88.48% Loss: 135.7519
# Epoch 14/75
#  390/391  [==============================] - Last batch accuracy: 0.8625 - Running epoch accuracy 0.8886
# Test accuracy: 88.88% Loss: 126.8727
# Epoch 15/75
#  390/391  [==============================] - Last batch accuracy: 0.8625 - Running epoch accuracy 0.8954
# Test accuracy: 89.37% Loss: 118.1958
# Epoch 16/75
#  390/391  [==============================] - Last batch accuracy: 0.9375 - Running epoch accuracy 0.9001
# Test accuracy: 89.36% Loss: 113.9152
# Epoch 17/75
#  390/391  [==============================] - Last batch accuracy: 0.8875 - Running epoch accuracy 0.9050
# Test accuracy: 90.04% Loss: 107.4715
# Epoch 18/75
#  390/391  [==============================] - Last batch accuracy: 0.9250 - Running epoch accuracy 0.9082
# Test accuracy: 89.39% Loss: 102.9490
# Epoch 19/75
#  390/391  [==============================] - Last batch accuracy: 0.9000 - Running epoch accuracy 0.9129
# Test accuracy: 89.58% Loss: 97.3793
# Epoch 20/75
#  390/391  [==============================] - Last batch accuracy: 0.9875 - Running epoch accuracy 0.9154
# Test accuracy: 90.29% Loss: 93.9470
# Epoch 21/75
#  390/391  [==============================] - Last batch accuracy: 0.9000 - Running epoch accuracy 0.9218
# Test accuracy: 90.17% Loss: 88.9327
# Epoch 22/75
#  390/391  [==============================] - Last batch accuracy: 0.9625 - Running epoch accuracy 0.9234
# Test accuracy: 90.58% Loss: 86.9712
# Epoch 23/75
#  390/391  [==============================] - Last batch accuracy: 0.8750 - Running epoch accuracy 0.9261
# Test accuracy: 90.80% Loss: 83.1948
# Epoch 24/75
#  390/391  [==============================] - Last batch accuracy: 0.9375 - Running epoch accuracy 0.9311
# Test accuracy: 91.24% Loss: 78.0822
# Epoch 25/75
#  390/391  [==============================] - Last batch accuracy: 0.9500 - Running epoch accuracy 0.9329
# Test accuracy: 90.85% Loss: 75.0644
# Epoch 26/75
#  390/391  [==============================] - Last batch accuracy: 0.9375 - Running epoch accuracy 0.9378
# Test accuracy: 90.09% Loss: 70.8267
# Epoch 27/75
#  390/391  [==============================] - Last batch accuracy: 0.9625 - Running epoch accuracy 0.9378
# Test accuracy: 90.91% Loss: 69.5042
# Epoch 28/75
#  390/391  [==============================] - Last batch accuracy: 0.9375 - Running epoch accuracy 0.9403
# Test accuracy: 91.06% Loss: 66.9680
# Epoch 29/75
#  390/391  [==============================] - Last batch accuracy: 0.9625 - Running epoch accuracy 0.9407
# Test accuracy: 90.61% Loss: 65.8942
# Epoch 30/75
#  390/391  [==============================] - Last batch accuracy: 0.9625 - Running epoch accuracy 0.9444
# Test accuracy: 91.08% Loss: 62.8779
# Epoch 31/75
#  390/391  [==============================] - Last batch accuracy: 0.9375 - Running epoch accuracy 0.9458
# Test accuracy: 91.70% Loss: 60.5632
# Epoch 32/75
#  390/391  [==============================] - Last batch accuracy: 0.9500 - Running epoch accuracy 0.9494
# Test accuracy: 90.54% Loss: 57.5637
# Epoch 33/75
#  390/391  [==============================] - Last batch accuracy: 0.9250 - Running epoch accuracy 0.9472
# Test accuracy: 91.64% Loss: 58.5768
# Epoch 34/75
#  390/391  [==============================] - Last batch accuracy: 0.9375 - Running epoch accuracy 0.9502
# Test accuracy: 91.23% Loss: 55.1498
# Epoch 35/75
#  390/391  [==============================] - Last batch accuracy: 0.9625 - Running epoch accuracy 0.9530
# Test accuracy: 92.15% Loss: 53.6827
# Epoch 36/75
#  390/391  [==============================] - Last batch accuracy: 0.9750 - Running epoch accuracy 0.9537
# Test accuracy: 91.17% Loss: 51.7869
# Epoch 37/75
#  390/391  [==============================] - Last batch accuracy: 0.9500 - Running epoch accuracy 0.9565
# Test accuracy: 91.56% Loss: 49.0483
# Epoch 38/75
#  390/391  [==============================] - Last batch accuracy: 0.9875 - Running epoch accuracy 0.9560
# Test accuracy: 91.43% Loss: 49.1075
# Epoch 39/75
#  390/391  [==============================] - Last batch accuracy: 0.9500 - Running epoch accuracy 0.9572
# Test accuracy: 91.20% Loss: 47.6116
# Epoch 40/75
#  390/391  [==============================] - Last batch accuracy: 0.9250 - Running epoch accuracy 0.9595
# Test accuracy: 91.01% Loss: 45.7644
# Epoch 41/75
#  390/391  [==============================] - Last batch accuracy: 0.9750 - Running epoch accuracy 0.9602
# Test accuracy: 91.92% Loss: 43.7841
# Epoch 42/75
#  390/391  [==============================] - Last batch accuracy: 0.9375 - Running epoch accuracy 0.9594
# Test accuracy: 91.48% Loss: 44.6014
# Epoch 43/75
#  390/391  [==============================] - Last batch accuracy: 0.9500 - Running epoch accuracy 0.9611
# Test accuracy: 91.77% Loss: 43.3155
# Epoch 44/75
#  390/391  [==============================] - Last batch accuracy: 0.9625 - Running epoch accuracy 0.9617
# Test accuracy: 91.78% Loss: 42.0157
# Epoch 45/75
#  390/391  [==============================] - Last batch accuracy: 0.9750 - Running epoch accuracy 0.9625
# Test accuracy: 91.65% Loss: 42.0898
# Epoch 46/75
#  390/391  [==============================] - Last batch accuracy: 0.9625 - Running epoch accuracy 0.9642
# Test accuracy: 91.76% Loss: 39.8068
# Epoch 47/75
#  390/391  [==============================] - Last batch accuracy: 0.9000 - Running epoch accuracy 0.9642
# Test accuracy: 91.73% Loss: 40.6957
# Epoch 48/75
#  390/391  [==============================] - Last batch accuracy: 0.9250 - Running epoch accuracy 0.9655
# Test accuracy: 92.29% Loss: 38.5376
# Epoch 49/75
#  390/391  [==============================] - Last batch accuracy: 0.9875 - Running epoch accuracy 0.9673
# Test accuracy: 91.44% Loss: 36.5756
# Epoch 50/75
#  390/391  [==============================] - Last batch accuracy: 0.9750 - Running epoch accuracy 0.9675
# Test accuracy: 92.35% Loss: 36.5286
# Epoch 51/75
#  390/391  [==============================] - Last batch accuracy: 0.9750 - Running epoch accuracy 0.9672
# Test accuracy: 92.21% Loss: 36.7814
# Epoch 52/75
#  390/391  [==============================] - Last batch accuracy: 0.9750 - Running epoch accuracy 0.9675
# Test accuracy: 91.57% Loss: 36.9690
# Epoch 53/75
#  390/391  [==============================] - Last batch accuracy: 0.9500 - Running epoch accuracy 0.9686
# Test accuracy: 92.01% Loss: 35.9671
# Epoch 54/75
#  390/391  [==============================] - Last batch accuracy: 0.9625 - Running epoch accuracy 0.9704
# Test accuracy: 91.71% Loss: 33.5909
# Epoch 55/75
#  390/391  [==============================] - Last batch accuracy: 0.9750 - Running epoch accuracy 0.9697
# Test accuracy: 92.43% Loss: 33.5955
# Epoch 56/75
#  390/391  [==============================] - Last batch accuracy: 0.9375 - Running epoch accuracy 0.9700
# Test accuracy: 92.26% Loss: 33.9562
# Epoch 57/75
#  390/391  [==============================] - Last batch accuracy: 0.9625 - Running epoch accuracy 0.9716
# Test accuracy: 92.03% Loss: 31.4805
# Epoch 58/75
#  390/391  [==============================] - Last batch accuracy: 0.9875 - Running epoch accuracy 0.9699
# Test accuracy: 91.99% Loss: 33.5279
# Epoch 59/75
#  390/391  [==============================] - Last batch accuracy: 1.0000 - Running epoch accuracy 0.9711
# Test accuracy: 92.20% Loss: 31.9880
# Epoch 60/75
#  390/391  [==============================] - Last batch accuracy: 0.9500 - Running epoch accuracy 0.9710
# Test accuracy: 92.34% Loss: 32.2092
# Epoch 61/75
#  390/391  [==============================] - Last batch accuracy: 0.9625 - Running epoch accuracy 0.9726
# Test accuracy: 92.21% Loss: 29.8872
# Epoch 62/75
#  390/391  [==============================] - Last batch accuracy: 0.9750 - Running epoch accuracy 0.9734
# Test accuracy: 92.24% Loss: 30.9239
# Epoch 63/75
#  390/391  [==============================] - Last batch accuracy: 0.9875 - Running epoch accuracy 0.9751
# Test accuracy: 91.88% Loss: 28.4298
# Epoch 64/75
#  390/391  [==============================] - Last batch accuracy: 0.9875 - Running epoch accuracy 0.9751
# Test accuracy: 92.58% Loss: 28.6595
# Epoch 65/75
#  390/391  [==============================] - Last batch accuracy: 0.9500 - Running epoch accuracy 0.9740
# Test accuracy: 92.06% Loss: 29.5579
# Epoch 66/75
#  390/391  [==============================] - Last batch accuracy: 0.9500 - Running epoch accuracy 0.9743
# Test accuracy: 91.95% Loss: 29.0019
# Epoch 67/75
#  390/391  [==============================] - Last batch accuracy: 0.9875 - Running epoch accuracy 0.9741
# Test accuracy: 92.29% Loss: 28.7984
# Epoch 68/75
#  390/391  [==============================] - Last batch accuracy: 0.9750 - Running epoch accuracy 0.9757
# Test accuracy: 92.30% Loss: 27.1921
# Epoch 69/75
#  390/391  [==============================] - Last batch accuracy: 0.9625 - Running epoch accuracy 0.9750
# Test accuracy: 92.64% Loss: 28.5002
# Epoch 70/75
#  390/391  [==============================] - Last batch accuracy: 0.9625 - Running epoch accuracy 0.9759
# Test accuracy: 92.36% Loss: 27.5124
# Epoch 71/75
#  390/391  [==============================] - Last batch accuracy: 1.0000 - Running epoch accuracy 0.9764
# Test accuracy: 92.18% Loss: 26.7414
# Epoch 72/75
#  390/391  [==============================] - Last batch accuracy: 0.9750 - Running epoch accuracy 0.9775
# Test accuracy: 92.07% Loss: 25.6082
# Epoch 73/75
#  390/391  [==============================] - Last batch accuracy: 1.0000 - Running epoch accuracy 0.9766
# Test accuracy: 92.34% Loss: 26.2850
# Epoch 74/75
#  390/391  [==============================] - Last batch accuracy: 0.9875 - Running epoch accuracy 0.9766
# Test accuracy: 92.38% Loss: 26.6118
# Epoch 75/75
#  390/391  [==============================] - Last batch accuracy: 0.9625 - Running epoch accuracy 0.9763
# Test accuracy: 92.66% Loss: 25.7488
# Best accuracy: 92.66%

# %% [markdown]
# **We can see that we get a test accuracy of 92.66 with 3.4 million parameters**

# %% [markdown]
# ###Forcing the model to converge with a lower learning rate

# %%
def train_best_model(activation="relu", fc_size=1024, dropout=0.25, optimizer="adam", learning_rate=0.001, epochs=75, batch_size=128):
    
    model = ResNet9(activation=activation, fc_size=fc_size, dropout=dropout).to(device)
    model.load_state_dict(torch.load('best_model.pth'))
    print(f"Number of trainable parameters: {sum(p.numel() for p in model.parameters() if p.requires_grad)}")
    optimizer = build_optimizer(model, optimizer, learning_rate)
    model.train()
    # Cross entropy loss 
    criterion = nn.CrossEntropyLoss()
    trainloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=2)
    best_accuracy=0
    progress_bar = ProgressBar()

    for epoch in range(1, epochs + 1):
        print('Epoch {}/{}'.format(epoch,epochs))
        running_loss = 0
        epoch_correct = 0
        epoch_total = 0
        for i, (inputs, targets) in enumerate(trainloader):

            inputs, targets = inputs.to(device), targets.to(device)

            # parameter gradients -> Zero
            optimizer.zero_grad()

            # Forward pass
            outputs = model(inputs)
            loss = criterion(outputs, targets)
            # Backward pass
            loss.backward()
            # Using our optimizer
            optimizer.step()

            running_loss += loss.item()
            _, predicted = outputs.max(1)
            batch_total = targets.size(0)
            batch_correct = predicted.eq(targets).sum().item()


            epoch_total += batch_total
            epoch_correct += batch_correct


            info_str = 'Last batch accuracy: {:.4f} - Running epoch accuracy {:.4f}'.\
                        format(batch_correct / batch_total, epoch_correct / epoch_total)
            progress_bar.update(max_value=len(trainloader), current_value=i, info=info_str)

        progress_bar.new_line()
        test_accuracy = test(model)
        if epoch > 30 and test_accuracy>best_accuracy:
            torch.save(model.state_dict(), "best_model_fine.pth")
            best_accuracy=test_accuracy
            
        print('Test accuracy: {:.2f}% Loss: {:.4f}'.format(test_accuracy*100,running_loss))
    print('Best accuracy: {:.2f}%'.format(best_accuracy*100))
train_best_model(learning_rate=0.0001)
# Out:
# Number of trainable parameters: 3499594
# Epoch 1/75
#  390/391  [==============================] - Last batch accuracy: 0.9875 - Running epoch accuracy 0.9847
# Test accuracy: 92.95% Loss: 18.0847
# Epoch 2/75
#  390/391  [==============================] - Last batch accuracy: 0.9750 - Running epoch accuracy 0.9869
# Test accuracy: 92.99% Loss: 14.6293
# Epoch 3/75
#  390/391  [==============================] - Last batch accuracy: 1.0000 - Running epoch accuracy 0.9883
# Test accuracy: 93.49% Loss: 13.2499
# Epoch 4/75
#  390/391  [==============================] - Last batch accuracy: 0.9750 - Running epoch accuracy 0.9883
# Test accuracy: 93.39% Loss: 13.4281
# Epoch 5/75
#  390/391  [==============================] - Last batch accuracy: 0.9875 - Running epoch accuracy 0.9891
# Test accuracy: 93.30% Loss: 12.2920
# Epoch 6/75
#  390/391  [==============================] - Last batch accuracy: 1.0000 - Running epoch accuracy 0.9896
# Test accuracy: 93.43% Loss: 11.7368
# Epoch 7/75
#  390/391  [==============================] - Last batch accuracy: 0.9875 - Running epoch accuracy 0.9904
# Test accuracy: 93.27% Loss: 10.9358
# Epoch 8/75
#  390/391  [==============================] - Last batch accuracy: 1.0000 - Running epoch accuracy 0.9905
# Test accuracy: 93.39% Loss: 11.1913
# Epoch 9/75
#  390/391  [==============================] - Last batch accuracy: 1.0000 - Running epoch accuracy 0.9908
# Test accuracy: 93.44% Loss: 10.4425
# Epoch 10/75
#  390/391  [==============================] - Last batch accuracy: 0.9750 - Running epoch accuracy 0.9919
# Test accuracy: 93.23% Loss: 9.4419
# Epoch 11/75
#  390/391  [==============================] - Last batch accuracy: 1.0000 - Running epoch accuracy 0.9908
# Test accuracy: 93.28% Loss: 10.4722
# Epoch 12/75
#  390/391  [==============================] - Last batch accuracy: 0.9875 - Running epoch accuracy 0.9914
# Test accuracy: 93.29% Loss: 9.8645
# Epoch 13/75
#  390/391  [==============================] - Last batch accuracy: 0.9875 - Running epoch accuracy 0.9915
# Test accuracy: 93.43% Loss: 10.0054
# Epoch 14/75
#  390/391  [==============================] - Last batch accuracy: 0.9875 - Running epoch accuracy 0.9918
# Test accuracy: 93.48% Loss: 9.6757
# Epoch 15/75
#  390/391  [==============================] - Last batch accuracy: 0.9875 - Running epoch accuracy 0.9917
# Test accuracy: 93.35% Loss: 9.5989
# Epoch 16/75
#  390/391  [==============================] - Last batch accuracy: 0.9750 - Running epoch accuracy 0.9924
# Test accuracy: 93.34% Loss: 8.9187
# Epoch 17/75
#  390/391  [==============================] - Last batch accuracy: 0.9875 - Running epoch accuracy 0.9925
# Test accuracy: 93.58% Loss: 8.6156
# Epoch 18/75
#  390/391  [==============================] - Last batch accuracy: 0.9875 - Running epoch accuracy 0.9926
# Test accuracy: 93.56% Loss: 8.8031
# Epoch 19/75
#  390/391  [==============================] - Last batch accuracy: 0.9875 - Running epoch accuracy 0.9923
# Test accuracy: 93.62% Loss: 8.8851
# Epoch 20/75
#  390/391  [==============================] - Last batch accuracy: 0.9875 - Running epoch accuracy 0.9925
# Test accuracy: 93.43% Loss: 8.5575
# Epoch 21/75
#  390/391  [==============================] - Last batch accuracy: 0.9875 - Running epoch accuracy 0.9931
# Test accuracy: 93.57% Loss: 8.4058
# Epoch 22/75
#  390/391  [==============================] - Last batch accuracy: 1.0000 - Running epoch accuracy 0.9928
# Test accuracy: 93.42% Loss: 8.5823
# Epoch 23/75
#  390/391  [==============================] - Last batch accuracy: 0.9875 - Running epoch accuracy 0.9934
# Test accuracy: 93.71% Loss: 8.0820
# Epoch 24/75
#  390/391  [==============================] - Last batch accuracy: 0.9875 - Running epoch accuracy 0.9934
# Test accuracy: 93.38% Loss: 8.0642
# Epoch 25/75
#  390/391  [==============================] - Last batch accuracy: 1.0000 - Running epoch accuracy 0.9927
# Test accuracy: 93.52% Loss: 8.4926
# Epoch 26/75
#  390/391  [==============================] - Last batch accuracy: 1.0000 - Running epoch accuracy 0.9934
# Test accuracy: 93.40% Loss: 8.0023
# Epoch 27/75
#  390/391  [==============================] - Last batch accuracy: 1.0000 - Running epoch accuracy 0.9933
# Test accuracy: 93.41% Loss: 7.6755
# Epoch 28/75
#  390/391  [==============================] - Last batch accuracy: 1.0000 - Running epoch accuracy 0.9928
# Test accuracy: 93.52% Loss: 8.1527
# Epoch 29/75
#  390/391  [==============================] - Last batch accuracy: 0.9875 - Running epoch accuracy 0.9939
# Test accuracy: 93.71% Loss: 7.0008
# Epoch 30/75
#  390/391  [==============================] - Last batch accuracy: 0.9875 - Running epoch accuracy 0.9931
# Test accuracy: 93.46% Loss: 7.9858
# Epoch 31/75
#  390/391  [==============================] - Last batch accuracy: 0.9875 - Running epoch accuracy 0.9941
# Test accuracy: 93.43% Loss: 7.0564
# Epoch 32/75
#  390/391  [==============================] - Last batch accuracy: 1.0000 - Running epoch accuracy 0.9939
# Test accuracy: 93.32% Loss: 7.6745
# Epoch 33/75
#  390/391  [==============================] - Last batch accuracy: 1.0000 - Running epoch accuracy 0.9930
# Test accuracy: 93.51% Loss: 7.9730
# Epoch 34/75
#  390/391  [==============================] - Last batch accuracy: 1.0000 - Running epoch accuracy 0.9939
# Test accuracy: 93.37% Loss: 7.1538
# Epoch 35/75
#  390/391  [==============================] - Last batch accuracy: 1.0000 - Running epoch accuracy 0.9945
# Test accuracy: 93.67% Loss: 6.6962
# Epoch 36/75
#  390/391  [==============================] - Last batch accuracy: 0.9875 - Running epoch accuracy 0.9943
# Test accuracy: 93.66% Loss: 6.7120
# Epoch 37/75
#  390/391  [==============================] - Last batch accuracy: 0.9750 - Running epoch accuracy 0.9938
# Test accuracy: 93.84% Loss: 7.1329
# Epoch 38/75
#  390/391  [==============================] - Last batch accuracy: 0.9875 - Running epoch accuracy 0.9941
# Test accuracy: 93.60% Loss: 6.8791
# Epoch 39/75
#  390/391  [==============================] - Last batch accuracy: 1.0000 - Running epoch accuracy 0.9939
# Test accuracy: 93.66% Loss: 6.9368
# Epoch 40/75
#  390/391  [==============================] - Last batch accuracy: 1.0000 - Running epoch accuracy 0.9942
# Test accuracy: 93.70% Loss: 6.7054
# Epoch 41/75
#  390/391  [==============================] - Last batch accuracy: 0.9875 - Running epoch accuracy 0.9948
# Test accuracy: 93.49% Loss: 6.5672
# Epoch 42/75
#  390/391  [==============================] - Last batch accuracy: 1.0000 - Running epoch accuracy 0.9943
# Test accuracy: 93.57% Loss: 6.6718
# Epoch 43/75
#  390/391  [==============================] - Last batch accuracy: 1.0000 - Running epoch accuracy 0.9944
# Test accuracy: 93.62% Loss: 6.5609
# Epoch 44/75
#  390/391  [==============================] - Last batch accuracy: 0.9875 - Running epoch accuracy 0.9940
# Test accuracy: 93.43% Loss: 7.0273
# Epoch 45/75
#  390/391  [==============================] - Last batch accuracy: 0.9875 - Running epoch accuracy 0.9944
# Test accuracy: 93.80% Loss: 6.4829
# Epoch 46/75
#  390/391  [==============================] - Last batch accuracy: 1.0000 - Running epoch accuracy 0.9947
# Test accuracy: 93.53% Loss: 6.0431
# Epoch 47/75
#  390/391  [==============================] - Last batch accuracy: 0.9875 - Running epoch accuracy 0.9943
# Test accuracy: 93.47% Loss: 6.7320
# Epoch 48/75
#  390/391  [==============================] - Last batch accuracy: 1.0000 - Running epoch accuracy 0.9940
# Test accuracy: 93.28% Loss: 6.9167
# Epoch 49/75
#  390/391  [==============================] - Last batch accuracy: 1.0000 - Running epoch accuracy 0.9944
# Test accuracy: 93.45% Loss: 6.5879
# Epoch 50/75
#  390/391  [==============================] - Last batch accuracy: 1.0000 - Running epoch accuracy 0.9943
# Test accuracy: 93.70% Loss: 6.9258
# Epoch 51/75
#  390/391  [==============================] - Last batch accuracy: 1.0000 - Running epoch accuracy 0.9942
# Test accuracy: 93.63% Loss: 6.8706
# Epoch 52/75
#  390/391  [==============================] - Last batch accuracy: 0.9750 - Running epoch accuracy 0.9942
# Test accuracy: 93.50% Loss: 6.3965
# Epoch 53/75
#  390/391  [==============================] - Last batch accuracy: 1.0000 - Running epoch accuracy 0.9945
# Test accuracy: 93.65% Loss: 6.9138
# Epoch 54/75
#  390/391  [==============================] - Last batch accuracy: 0.9875 - Running epoch accuracy 0.9952
# Test accuracy: 93.76% Loss: 5.9809
# Epoch 55/75
#  390/391  [==============================] - Last batch accuracy: 1.0000 - Running epoch accuracy 0.9946
# Test accuracy: 93.85% Loss: 6.1669
# Epoch 56/75
#  390/391  [==============================] - Last batch accuracy: 1.0000 - Running epoch accuracy 0.9947
# Test accuracy: 93.53% Loss: 6.4591
# Epoch 57/75
#  390/391  [==============================] - Last batch accuracy: 1.0000 - Running epoch accuracy 0.9948
# Test accuracy: 93.54% Loss: 5.8821
# Epoch 58/75
#  390/391  [==============================] - Last batch accuracy: 1.0000 - Running epoch accuracy 0.9944
# Test accuracy: 93.52% Loss: 6.3608
# Epoch 59/75
#  390/391  [==============================] - Last batch accuracy: 1.0000 - Running epoch accuracy 0.9951
# Test accuracy: 93.55% Loss: 5.9039
# Epoch 60/75
#  390/391  [==============================] - Last batch accuracy: 1.0000 - Running epoch accuracy 0.9945
# Test accuracy: 93.54% Loss: 6.4042
# Epoch 61/75
#  390/391  [==============================] - Last batch accuracy: 1.0000 - Running epoch accuracy 0.9947
# Test accuracy: 93.56% Loss: 6.2308
# Epoch 62/75
#  390/391  [==============================] - Last batch accuracy: 0.9875 - Running epoch accuracy 0.9952
# Test accuracy: 93.81% Loss: 5.7365
# Epoch 63/75
#  390/391  [==============================] - Last batch accuracy: 0.9875 - Running epoch accuracy 0.9947
# Test accuracy: 93.66% Loss: 5.8027
# Epoch 64/75
#  390/391  [==============================] - Last batch accuracy: 1.0000 - Running epoch accuracy 0.9949
# Test accuracy: 93.39% Loss: 6.2451
# Epoch 65/75
#  390/391  [==============================] - Last batch accuracy: 1.0000 - Running epoch accuracy 0.9951
# Test accuracy: 93.33% Loss: 5.9312
# Epoch 66/75
#  390/391  [==============================] - Last batch accuracy: 1.0000 - Running epoch accuracy 0.9947
# Test accuracy: 93.69% Loss: 6.1175
# Epoch 67/75
#  390/391  [==============================] - Last batch accuracy: 1.0000 - Running epoch accuracy 0.9952
# Test accuracy: 93.50% Loss: 5.3649
# Epoch 68/75
#  390/391  [==============================] - Last batch accuracy: 0.9875 - Running epoch accuracy 0.9951
# Test accuracy: 93.44% Loss: 5.7913
# Epoch 69/75
#  390/391  [==============================] - Last batch accuracy: 1.0000 - Running epoch accuracy 0.9951
# Test accuracy: 93.26% Loss: 5.6103
# Epoch 70/75
#  390/391  [==============================] - Last batch accuracy: 1.0000 - Running epoch accuracy 0.9950
# Test accuracy: 93.57% Loss: 5.5718
# Epoch 71/75
#  390/391  [==============================] - Last batch accuracy: 0.9875 - Running epoch accuracy 0.9951
# Test accuracy: 93.67% Loss: 5.7806
# Epoch 72/75
#  390/391  [==============================] - Last batch accuracy: 1.0000 - Running epoch accuracy 0.9952
# Test accuracy: 93.43% Loss: 5.6400
# Epoch 73/75
#  390/391  [==============================] - Last batch accuracy: 0.9875 - Running epoch accuracy 0.9949
# Test accuracy: 93.62% Loss: 5.5417
# Epoch 74/75
#  390/391  [==============================] - Last batch accuracy: 1.0000 - Running epoch accuracy 0.9956
# Test accuracy: 93.73% Loss: 5.1691
# Epoch 75/75
#  390/391  [==============================] - Last batch accuracy: 0.9875 - Running epoch accuracy 0.9956
# Test accuracy: 93.88% Loss: 5.3642
# Best accuracy: 93.88%

# %% [markdown]
# #Final Accuracy:

# %%
model = ResNet9(activation="relu", fc_size=1024, dropout=0.25).to(device)
model.load_state_dict(torch.load('best_model_fine.pth'))
print("Final Model with best Accuracy: {:.2f}%".format(test(model)*100))
# Out:
# Final Model with best Accuracy: 93.88%
